# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderGir/python_lessions/blob/Math-HW_1/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0, 20, 0.1)
k1 = 1
k2 = 66
plt.plot(x, np.cos(k1 * x))
plt.plot(x, np.cos(k2 * x))
